# %% [markdown]
# # Chicken-threat dataset preparation
# Run this launcher in Colab. It keeps inspection interactive while the dataset logic remains in the repository.

# %%
REPOSITORY_URL = "https://github.com/Dumdart/SmartHomeBridge.git"
COMMIT_SHA = "SET_THE_REVIEWED_COMMIT_SHA"
METADATA_CSV = "/content/drive/MyDrive/chicken-threat/source_metadata.csv"
OUTPUT_DIR = "/content/drive/MyDrive/chicken-threat/outputs"
DATASET_VERSION = "v5.0.0"

# %%
# !git clone $REPOSITORY_URL SmartHomeBridge
# %cd SmartHomeBridge
# !git checkout $COMMIT_SHA
# %pip install -q uv
# !uv sync --extra ml --locked
# !uv run smart-home-ml-build-dataset --metadata $METADATA_CSV --output-dir $OUTPUT_DIR --class-mapping ml/chicken_threat/configs/class_mapping.yaml --dataset-config ml/chicken_threat/configs/dataset.yaml --version $DATASET_VERSION

# %% [markdown]
# Open `inspection_report.html` and inspect `inspection_bundle.zip` before manually publishing the full dataset archive to Kaggle. Do not edit the generated dataset directly.
