# %% [markdown]
# # Chicken-threat dataset preparation
# Run this launcher locally from the repository root. Source data and generated artifacts stay in the gitignored `ml/chicken_threat/work/` workspace.

# %%
from pathlib import Path

WORKSPACE = Path("ml/chicken_threat/work")
METADATA_CSV = WORKSPACE / "source_metadata.csv"
OUTPUT_DIR = WORKSPACE / "datasets"
DATASET_VERSION = "v5.0.0"

print(f"Place source data and {METADATA_CSV.name} below {WORKSPACE.resolve()}")

# %%
# !uv run smart-home-ml-prepare-local-dataset --workspace $WORKSPACE --version $DATASET_VERSION

# %% [markdown]
# Open `datasets/<version>/inspection_report.html` and inspect `datasets/<version>/inspection_bundle.zip` before manually publishing the dataset archive to Kaggle. Do not edit the generated dataset directly.
