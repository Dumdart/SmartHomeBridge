# %% [markdown]
# # Chicken-threat dataset preparation
# Run this launcher locally from the repository root. Source data and generated artifacts stay in the gitignored `ml/chicken_threat/work/` workspace.

# %%
from pathlib import Path

WORKSPACE = Path("ml/chicken_threat/work")
METADATA_CSV = WORKSPACE / "source_metadata.csv"
OUTPUT_DIR = WORKSPACE / "datasets"
DATASET_VERSION = "v5.0.0"

print(f"Run smart-home-ml-download-datasets to create {METADATA_CSV.name} below {WORKSPACE.resolve()}")

# %%
# Set ROBOFLOW_API_KEY in the shell environment before executing this cell.
# !uv run --extra ml smart-home-ml-download-datasets --workspace $WORKSPACE

# %%
# !uv run --extra ml smart-home-ml-prepare-local-dataset --workspace $WORKSPACE --version $DATASET_VERSION

# %% [markdown]
# Inspect `download_report.json`, then open `datasets/<version>/inspection_report.html` and inspect `datasets/<version>/inspection_bundle.zip` before manually publishing the dataset archive to Kaggle. Do not edit the generated dataset directly.
